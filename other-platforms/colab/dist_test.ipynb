# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# %cd 'gdrive/MyDrive/ML for Precision Medicine/Precision Medicine MSc/RP/Reaction Modelling/Code/ts_gen'
# Out:
# Mounted at /content/gdrive/
# /content/gdrive/MyDrive/ML for Precision Medicine/Precision Medicine MSc/RP/Reaction Modelling/Code/ts_gen

# %%
# !git config --global user.email

# %%
# !git add . && git commit -m "colab commit, doing this for gpus"
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@5675a545efe4.(none)')

# %%
# !conda env create -f tsir-rdkit-env.yml
